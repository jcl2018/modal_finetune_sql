# %% [markdown]
# # Finetuning LLaMa + Text-to-SQL
#
# This walkthrough shows you how to fine-tune LLaMa-7B on a Text-to-SQL dataset, and then use it for inference against
# any database of structured data using LlamaIndex.
#
# **NOTE**: This code is taken and adapted from Modal's `doppel-bot` repo: https://github.com/modal-labs/doppel-bot.
# **NOTE**: A lot of the code is contained in the underlying Python scripts in the `src` directory. We definitely encourage you to go and take a look!

# %% [markdown]
# ### Setup
#
# NOTE: you will need to setup a Modal account + token in order to use this notebook.

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: modal-client==0.50.3044 in e:\llama_text_to_sql\venv\lib\site-packages (from -r requirements.txt (line 1)) (0.50.3044)
# Requirement already satisfied: llama-index==0.8.2.post1 in e:\llama_text_to_sql\venv\lib\site-packages (from -r requirements.txt (line 2)) (0.8.2.post1)
# Requirement already satisfied: datasets==2.14.4 in e:\llama_text_to_sql\venv\lib\site-packages (from -r requirements.txt (line 3)) (2.14.4)
# Requirement already satisfied: peft in e:\llama_text_to_sql\venv\lib\site-packages (from -r requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: toml in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (7.1.0)
# Requirement already satisfied: rich>=12.0.0 in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (13.7.1)
# Requirement already satisfied: cloudpickle<2.1.0,>=2.0.0 in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: asgiref in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (3.8.1)
# Requirement already satisfied: click>=8.1.0 in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: typer~=0.9.0 in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (0.9.4)
# Requirement already satisfied: fastapi in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (0.110.1)
# Requirement already satisfied: watchfiles in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (0.21.0)
# Requirement already satisfied: tblib>=1.7.0 in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: certifi in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (2024.2.2)
# Requirement already satisfied: aiostream in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (0.5.2)
# Requirement already satisfied: protobuf!=4.24.0,<5.0,>=3.19 in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (4.25.3)
# Requirement already satisfied: typing-extensions~=4.6 in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: aiohttp in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (3.9.4)
# Requirement already satisfied: grpclib==0.4.3 in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: types-toml in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (0.10.8.20240310)
# Requirement already satisfied: synchronicity~=0.5.3 in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: types-certifi in e:\llama_text_to_sql\venv\lib\site-packages (from modal-client==0.50.3044->-r requirements.txt (line 1)) (2021.10.8.3)
# Requirement already satisfied: pandas in e:\llama_text_to_sql\venv\lib\site-packages (from llama-index==0.8.2.post1->-r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: tiktoken in e:\llama_text_to_sql\venv\lib\site-packages (from llama-index==0.8.2.post1->-r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: urllib3<2 in e:\llama_text_to_sql\venv\lib\site-packages (from llama-index==0.8.2.post1->-r requirements.txt (line 2)) (1.26.18)
# Requirement already satisfied: fsspec>=2023.5.0 in e:\llama_text_to_sql\venv\lib\site-packages (from llama-index==0.8.2.post1->-r requirements.txt (line 2)) (2024.3.1)
# Requirement already satisfied: dataclasses-json in e:\llama_text_to_sql\venv\lib\site-packages (from llama-index==0.8.2.post1->-r requirements.txt (line 2)) (0.6.4)
# Requirement already satisfied: langchain>=0.0.262 in e:\llama_text_to_sql\venv\lib\site-packages (from llama-index==0.8.2.post1->-r requirements.txt (line 2)) (0.1.16)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in e:\llama_text_to_sql\venv\lib\site-packages (from llama-index==0.8.2.post1->-r requirements.txt (line 2)) (8.2.3)
# Requirement already satisfied: openai>=0.26.4 in e:\llama_text_to_sql\venv\lib\site-packages (from llama-index==0.8.2.post1->-r requirements.txt (line 2)) (1.17.1)
# Requirement already satisfied: beautifulsoup4 in e:\llama_text_to_sql\venv\lib\site-packages (from llama-index==0.8.2.post1->-r requirements.txt (line 2)) (4.12.3)
# Requirement already satisfied: numpy in e:\llama_text_to_sql\venv\lib\site-packages (from llama-index==0.8.2.post1->-r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: sqlalchemy>=2.0.15 in e:\llama_text_to_sql\venv\lib\site-packages (from llama-index==0.8.2.post1->-r requirements.txt (line 2)) (2.0.29)
# Requirement already satisfied: typing-inspect>=0.8.0 in e:\llama_text_to_sql\venv\lib\site-packages (from llama-index==0.8.2.post1->-r requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: nest-asyncio in e:\llama_text_to_sql\venv\lib\site-packages (from llama-index==0.8.2.post1->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: requests>=2.19.0 in e:\llama_text_to_sql\venv\lib\site-packages (from datasets==2.14.4->-r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in e:\llama_text_to_sql\venv\lib\site-packages (from datasets==2.14.4->-r requirements.txt (line 3)) (4.66.2)
# Requirement already satisfied: pyarrow>=8.0.0 in e:\llama_text_to_sql\venv\lib\site-packages (from datasets==2.14.4->-r requirements.txt (line 3)) (15.0.2)
# Requirement already satisfied: packaging in e:\llama_text_to_sql\venv\lib\site-packages (from datasets==2.14.4->-r requirements.txt (line 3)) (23.2)
# Requirement already satisfied: xxhash in e:\llama_text_to_sql\venv\lib\site-packages (from datasets==2.14.4->-r requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: multiprocess in e:\llama_text_to_sql\venv\lib\site-packages (from datasets==2.14.4->-r requirements.txt (line 3)) (0.70.15)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in e:\llama_text_to_sql\venv\lib\site-packages (from datasets==2.14.4->-r requirements.txt (line 3)) (0.22.2)
# Requirement already satisfied: pyyaml>=5.1 in e:\llama_text_to_sql\venv\lib\site-packages (from datasets==2.14.4->-r requirements.txt (line 3)) (6.0.1)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in e:\llama_text_to_sql\venv\lib\site-packages (from datasets==2.14.4->-r requirements.txt (line 3)) (0.3.7)
# Requirement already satisfied: h2<5,>=3.1.0 in e:\llama_text_to_sql\venv\lib\site-packages (from grpclib==0.4.3->modal-client==0.50.3044->-r requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: multidict in e:\llama_text_to_sql\venv\lib\site-packages (from grpclib==0.4.3->modal-client==0.50.3044->-r requirements.txt (line 1)) (6.0.5)
# Requirement already satisfied: torch>=1.13.0 in e:\llama_text_to_sql\venv\lib\site-packages (from peft->-r requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: transformers in e:\llama_text_to_sql\venv\lib\site-packages (from peft->-r requirements.txt (line 4)) (4.39.3)
# Requirement already satisfied: accelerate>=0.21.0 in e:\llama_text_to_sql\venv\lib\site-packages (from peft->-r requirements.txt (line 4)) (0.29.2)
# Requirement already satisfied: psutil in e:\llama_text_to_sql\venv\lib\site-packages (from peft->-r requirements.txt (line 4)) (5.9.8)
# Requirement already satisfied: safetensors in e:\llama_text_to_sql\venv\lib\site-packages (from peft->-r requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: colorama in e:\llama_text_to_sql\venv\lib\site-packages (from click>=8.1.0->modal-client==0.50.3044->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: attrs>=17.3.0 in e:\llama_text_to_sql\venv\lib\site-packages (from aiohttp->modal-client==0.50.3044->-r requirements.txt (line 1)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\llama_text_to_sql\venv\lib\site-packages (from aiohttp->modal-client==0.50.3044->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in e:\llama_text_to_sql\venv\lib\site-packages (from aiohttp->modal-client==0.50.3044->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in e:\llama_text_to_sql\venv\lib\site-packages (from aiohttp->modal-client==0.50.3044->-r requirements.txt (line 1)) (1.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in e:\llama_text_to_sql\venv\lib\site-packages (from aiohttp->modal-client==0.50.3044->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: filelock in e:\llama_text_to_sql\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.4->-r requirements.txt (line 3)) (3.13.4)
# Requirement already satisfied: zipp>=0.5 in e:\llama_text_to_sql\venv\lib\site-packages (from importlib-metadata>=3.6.0->modal-client==0.50.3044->-r requirements.txt (line 1)) (3.18.1)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.42 in e:\llama_text_to_sql\venv\lib\site-packages (from langchain>=0.0.262->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (0.1.42)
# Requirement already satisfied: langchain-community<0.1,>=0.0.32 in e:\llama_text_to_sql\venv\lib\site-packages (from langchain>=0.0.262->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (0.0.32)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in e:\llama_text_to_sql\venv\lib\site-packages (from langchain>=0.0.262->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (0.1.47)
# Requirement already satisfied: pydantic<3,>=1 in e:\llama_text_to_sql\venv\lib\site-packages (from langchain>=0.0.262->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (2.7.0)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in e:\llama_text_to_sql\venv\lib\site-packages (from langchain>=0.0.262->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (0.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in e:\llama_text_to_sql\venv\lib\site-packages (from langchain>=0.0.262->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (1.33)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in e:\llama_text_to_sql\venv\lib\site-packages (from dataclasses-json->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (3.21.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\llama_text_to_sql\venv\lib\site-packages (from openai>=0.26.4->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (0.27.0)
# Requirement already satisfied: sniffio in e:\llama_text_to_sql\venv\lib\site-packages (from openai>=0.26.4->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: distro<2,>=1.7.0 in e:\llama_text_to_sql\venv\lib\site-packages (from openai>=0.26.4->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (1.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in e:\llama_text_to_sql\venv\lib\site-packages (from openai>=0.26.4->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (4.3.0)
# Requirement already satisfied: idna<4,>=2.5 in e:\llama_text_to_sql\venv\lib\site-packages (from requests>=2.19.0->datasets==2.14.4->-r requirements.txt (line 3)) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\llama_text_to_sql\venv\lib\site-packages (from requests>=2.19.0->datasets==2.14.4->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\llama_text_to_sql\venv\lib\site-packages (from rich>=12.0.0->modal-client==0.50.3044->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\llama_text_to_sql\venv\lib\site-packages (from rich>=12.0.0->modal-client==0.50.3044->-r requirements.txt (line 1)) (2.17.2)
# Requirement already satisfied: greenlet!=0.4.17 in e:\llama_text_to_sql\venv\lib\site-packages (from sqlalchemy>=2.0.15->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: sigtools==4.0.1 in e:\llama_text_to_sql\venv\lib\site-packages (from synchronicity~=0.5.3->modal-client==0.50.3044->-r requirements.txt (line 1)) (4.0.1)
# Requirement already satisfied: sympy in e:\llama_text_to_sql\venv\lib\site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 4)) (1.12)
# Requirement already satisfied: jinja2 in e:\llama_text_to_sql\venv\lib\site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 4)) (3.1.3)
# Requirement already satisfied: networkx in e:\llama_text_to_sql\venv\lib\site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 4)) (3.2.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in e:\llama_text_to_sql\venv\lib\site-packages (from typing-inspect>=0.8.0->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: soupsieve>1.2 in e:\llama_text_to_sql\venv\lib\site-packages (from beautifulsoup4->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (2.5)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in e:\llama_text_to_sql\venv\lib\site-packages (from fastapi->modal-client==0.50.3044->-r requirements.txt (line 1)) (0.37.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\llama_text_to_sql\venv\lib\site-packages (from pandas->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in e:\llama_text_to_sql\venv\lib\site-packages (from pandas->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\llama_text_to_sql\venv\lib\site-packages (from pandas->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: regex>=2022.1.18 in e:\llama_text_to_sql\venv\lib\site-packages (from tiktoken->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in e:\llama_text_to_sql\venv\lib\site-packages (from transformers->peft->-r requirements.txt (line 4)) (0.15.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in e:\llama_text_to_sql\venv\lib\site-packages (from anyio<5,>=3.5.0->openai>=0.26.4->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: hpack<5,>=4.0 in e:\llama_text_to_sql\venv\lib\site-packages (from h2<5,>=3.1.0->grpclib==0.4.3->modal-client==0.50.3044->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in e:\llama_text_to_sql\venv\lib\site-packages (from h2<5,>=3.1.0->grpclib==0.4.3->modal-client==0.50.3044->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: httpcore==1.* in e:\llama_text_to_sql\venv\lib\site-packages (from httpx<1,>=0.23.0->openai>=0.26.4->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in e:\llama_text_to_sql\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=0.26.4->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\llama_text_to_sql\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain>=0.0.262->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in e:\llama_text_to_sql\venv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain>=0.0.262->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (3.10.0)
# Requirement already satisfied: mdurl~=0.1 in e:\llama_text_to_sql\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->modal-client==0.50.3044->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: annotated-types>=0.4.0 in e:\llama_text_to_sql\venv\lib\site-packages (from pydantic<3,>=1->langchain>=0.0.262->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in e:\llama_text_to_sql\venv\lib\site-packages (from pydantic<3,>=1->langchain>=0.0.262->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (2.18.1)
# Requirement already satisfied: six>=1.5 in e:\llama_text_to_sql\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index==0.8.2.post1->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\llama_text_to_sql\venv\lib\site-packages (from jinja2->torch>=1.13.0->peft->-r requirements.txt (line 4)) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in e:\llama_text_to_sql\venv\lib\site-packages (from sympy->torch>=1.13.0->peft->-r requirements.txt (line 4)) (1.3.0)
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Load Training Data for Finetuning LLaMa
#
# We load data from `b-mc2/sql-create-context` on Hugging Face: https://huggingface.co/datasets/b-mc2/sql-create-context.
#
# This dataset consists of tuples of natural language queries, create table statements, and ground-truth SQL queries. This is the dataset that we use to finetune our SQL model.

# %%
data_dir = "data_sql"

# !modal run src.load_data_sql --data-dir {data_dir}
# Out:
# Traceback (most recent call last):
#   File "C:\Users\chang\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\chang\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "E:\llama_text_to_sql\venv\Scripts\modal.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "E:\llama_text_to_sql\venv\lib\site-packages\modal\__main__.py", line 6, in main
#     entrypoint_cli()
#   File "E:\llama_text_to_sql\venv\lib\site-packages\click\core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#   File "E:\llama_text_to_sql\venv\lib\site-packages\typer\core.py", line 783, in main
#     return _main(
#   File "E:\llama_text_to_sql\venv\lib\site-packages\typer\core.py", line 225, in _main
#     rv = self.invoke(ctx)
#   File "E:\llama_text_to_sql\venv\lib\site-packages\click\core.py", line 1688, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "E:\llama_text_to_sql\venv\lib\site-packages\click\core.py", line 1688, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "E:\llama_text_to_sql\venv\lib\site-packages\click\core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "E:\llama_text_to_sql\venv\lib\site-packages\click\core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#   File "E:\llama_text_to_sql\venv\lib\site-packages\click\decorators.py", line 33, in new_func
#     return f(get_current_context(), *args, **kwargs)
#   File "E:\llama_text_to_sql\venv\lib\site-packages\modal\cli\run.py", line 101, in f
#     with run_stub(
#   File "E:\llama_text_to_sql\venv\lib\site-packages\synchronicity\synchronizer.py", line 497, in proxy_method
#     return wrapped_method(instance, *args, **kwargs)
#   File "E:\llama_text_to_sql\venv\lib\site-packages\synchronicity\combined_types.py", line 26, in __call__
#     raise uc_exc.exc from None
#   File "C:\Users\chang\AppData\Local\Programs\Python\Python39\lib\contextlib.py", line 181, in __aenter__
#     return await self.gen.__anext__()
#   File "E:\llama_text_to_sql\venv\lib\site-packages\modal\runner.py", line 56, in _run_stub
#     client = await _Client.from_env()
#   File "E:\llama_text_to_sql\venv\lib\site-packages\modal\client.py", line 236, in from_env
#     raise AuthError(creds_missing_msg)
# modal.exception.AuthError: Token missing. Could not authenticate client. If you have token credentials, see modal.com/docs/reference/modal.config for setup help. If you are a new user, register an account at modal.com, then run `modal token new`.

# %% [markdown]
# ### Run Finetuning Script
#
# We run our finetuning script on the loaded dataset.
# The finetuning script contains the following components:
# - We split the dataset into training and validation splits.
# - We format each split into input/output tuples of token id's. This means that the labels are the same as inputs (loss signal is measured on full input, not just on the generated portion).
# - We use `LoraConfig` from `peft` for efficient fine-tuning.
# - We use `transformers.Trainer` to actually run the training process.
# - If a valid `WANDB_PROJECT` is specified, along with the relevant secret in Modal, then we will log results to wandb.
#
# We use Modal to spin up an A100 to run our finetuning code.

# %%
data_dir = "data_sql"

# !modal run src.finetune_sql --data-dir {data_dir}

# %% [markdown]
# ### Evaluation
#
# We provide a basic evaluation script over sample data from `sql-create-context` so that you can see for yourself how well the finetuned model performs vs. the baseline model.

# %%
# !modal run src.eval_sql::main
# Out:
# ✓ Initialized. View app at https://modal.com/apps/ap-JS10MTVAhat3jK4K8QwKyv
# ⠋ Initializing...
# ⠼ Creating objects...objects...
# ├── ⠋ Creating download_models...
# └── ⠋ Creating mount /Users/jerryliu/Programming/modal_finetune_sql/src:
# ⠧ Creating objects...
# ├── ⠸ Creating download_models...
# └── ⠸ Creating mount /Users/jerryliu/Programming/modal_finetune_sql/src:
# ⠋ Creating objects...
# ├── ⠦ Creating download_models...
# └── ⠦ Creating mount /Users/jerryliu/Programming/modal_finetune_sql/src:
# ⠸ Creating objects...
# ├── ⠏ Creating download_models...
# └── ⠏ Creating mount /Users/jerryliu/Programming/modal_finetune_sql/src:
# ⠦ Creating objects...
# ├── ⠹ Creating download_models...
# ⠋ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠦ Creating download_models...
# ⠸ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠏ Creating download_models...
# ⠦ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠹ Creating download_models...
# ⠏ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ⠹ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ⠦ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ⠏ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ⠹ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ⠴ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ⠇ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ⠙ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ⠴ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠋ Creating run_evals...
# └── ⠋ Creating mount /Users/jerryliu/Programming/modal_finetune_sql/src:
# ⠇ Creating objects...
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠸ Creating run_evals...
# └── ⠸ Creating mount /Users/jerryliu/Programming/modal_finetune_sql/src:
# ⠙ Creating objects...
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠦ Creating run_evals...
# ⠼ Creating objects...amming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠏ Creating run_evals...
# ⠧ Creating objects...amming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠹ Creating run_evals...
# ⠙ Creating objects...amming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠴ Creating run_evals...
# ⠼ Creating objects...amming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠏ Creating run_evals...
# ⠧ Creating objects...amming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠹ Creating run_evals...
# ⠋ Creating objects...amming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠴ Creating run_evals...
# ⠸ Creating objects...amming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created run_evals.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ⠧ Creating objects...
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created run_evals.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ⠋ Creating objects...
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created run_evals.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ⠸ Creating objects...
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created run_evals.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ⠦ Creating objects...
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created run_evals.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ⠏ Creating objects...
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created run_evals.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ⠹ Creating objects...
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created run_evals.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# └── 🔨 Created run_evals_all.
# ✓ Created objects.
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created run_evals.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# └── 🔨 Created run_evals_all.
# ⠧ Running (0/1 containers active)... View app at
# ⠋ Running (0/1 containers active)... View app at
# ⠼ Running (0/1 containers active)... View app at
# ⠧ Running (0/1 containers active)... View app at
# ⠋ Running (0/1 containers active)... View app at
# ⠸ Loading images (1 containers initializing)... View app at
# ⠦ Loading images (1 containers initializing)... View app at
# ⠏ Loading images (1 containers initializing)... View app at
# ⠸ Loading images (1 containers initializing)... View app at
# ⠦ Loading images (1 containers initializing)... View app at
# ⠏ Loading images (1 containers initializing)... View app at
# ⠹ Loading images (1 containers initializing)... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠏ Loading images (1 containers initializing)... View app at
# ⠹ Loading images (1 containers initializing)... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠼ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠼ Loading images (1 containers initializing)... View app at
# ⠧ Loading images (1 containers initializing)... View app at
# ⠋ Loading images (1 containers initializing)... View app at
# ⠸ Loading images (1 containers initializing)... View app at
# ⠧ Loading images (1 containers initializing)... View app at
# ⠋ Loading images (1 containers initializing)... View app at
# ⠸ Loading images (1 containers initializing)... View app at
# ⠦ Loading images (1 containers initializing)... View app at
# ⠏ Loading images (1 containers initializing)... View app at
# ⠹ Loading images (1 containers initializing)... View app at
# ⠦ Loading images (1 containers initializing)... View app at
# ⠏ Loading images (1 containers initializing)... View app at
# ⠹ Loading images (1 containers initializing)... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠹ Loading images (1 containers initializing)... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠼ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠼ Loading images (1 containers initializing)... View app at
# ⠧ Loading images (1 containers initializing)... View app at
# ⠋ Loading images (1 containers initializing)... View app at
# ⠸ Loading images (1 containers initializing)... View app at
# ⠧ Loading images (1 containers initializing)... View app at
# ⠋ Loading images (1 containers initializing)... View app at
# ⠸ Loading images (1 containers initializing)... View app at
# ⠦ Loading images (1 containers initializing)... View app at
# ⠏ Loading images (1 containers initializing)... View app at
# ⠸ Loading images (1 containers initializing)... View app at
# ⠦ Loading images (1 containers initializing)... View app at
# ⠏ Loading images (1 containers initializing)... View app at
# ⠹ Loading images (1 containers initializing)... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠹ Loading images (1 containers initializing)... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠼ Loading images (1 containers initializing)... View app at
# ⠧ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠼ Loading images (1 containers initializing)... View app at
# ⠧ Loading images (1 containers initializing)... View app at
# ⠋ Loading images (1 containers initializing)... View app at
# ⠸ Loading images (1 containers initializing)... View app at
# ⠦ Loading images (1 containers initializing)... View app at
# ⠋ Loading images (1 containers initializing)... View app at
# ⠸ Loading images (1 containers initializing)... View app at
# ⠦ Loading images (1 containers initializing)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-d5b377c3e59db227/0.0.0/0f7e3662623656454fcd2b650f34e886a7db4b9104504885bd462096cc7a9f51...
# ⠧ Running (1/1 containers active)... View app at https://modal.com/apps/ap-JS10M
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]Downloading data files: 100%|██████████| 1/1 [00:00<00:00, 4424.37it/s]10M
# ⠇ Running (1/1 containers active)... View app at https://modal.com/apps/ap-JS10M
# ⠏ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-JS10M
# ⠹ Running (1/1 containers active)... View app at
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files: 100%|██████████| 1/1 [00:00<00:00,  1.74it/s]Extracting data files: 100%|██████████| 1/1 [00:00<00:00,  1.74it/s]
# ⠴ Running (1/1 containers active)... View app at https://modal.com/apps/ap-JS10M
# ⠴ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-JS10M
# Generating train split: 0 examples [00:00, ? examples/s]
# ⠇ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-JS10M
# Generating train split: 40675 examples [00:00, 139262.56 examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-d5b377c3e59db227/0.0.0/0f7e3662623656454fcd2b650f34e886a7db4b9104504885bd462096cc7a9f51. Subsequent calls will reuse this data.
# m Running (1/1 containers active)... View app at https://modal.com/apps/ap-JS10M
#   0%|          | 0/1 [00:00<?, ?it/s]100%|██████████| 1/1 [00:00<00:00, 52.54it/s]p at https://modal.com/apps/ap-JS10M
# *** Running inference with finetuned model ***tive)... View app at https://modal.com/apps/ap-JS10M
# ⠹ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-JS10M
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# s://modal.com/apps/ap-JS10MTVAhat3jK4K8QwKyv
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# ⠦ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-JS10M
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# s://modal.com/apps/ap-JS10MTVAhat3jK4K8QwKyv
# ⠦ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-JS10M
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at ⠧ Running (1/1 containers active)... View app at https://modal.com/apps/ap-JS10M
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# s://modal.com/apps/ap-JS10MTVAhat3jK4K8QwKyv
# ⠇ Worker assigned... View app at 9mView app at https://modal.com/apps/ap-JS10MTVAhat3jK4K8QwKy
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠋ Worker assigned... View app at 02:17<04:35, 137.73s/it]⠇ Worker assigned... View app at https://modal.com/apps/ap-JS10MTVAhat3jK4K8QwKy
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ...
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠸ Worker assigned... View app at
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# ⠴ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠇ Worker assigned... View app at
# ⠙ Worker assigned... View app at
# ⠼ Worker assigned... View app at
# ⠧ Worker assigned... View app at
# ⠋ Worker assigned... View app at
# ************ Row {idx} ************hat3jK4K8QwKyv
# ⠙ Worker assigned... View app at
# Input 0: {'input': 'Who was the winning driver at Okayama International
# Circuit?', 'context': 'CREATE TABLE table_16670746_2 (winning_driver VARCHAR,
# circuit VARCHAR)', 'output': 'SELECT winning_driver FROM table_16670746_2 WHERE
# circuit = "Okayama International circuit"'}
# ⠙ Worker assigned... View app at
# Output 0 (finetuned model): SELECT * FROM `table_16670746` WHERE
# `winning_driver` = '<NAME>' AND    circuit = '<NAME>';
# ⠙ Worker assigned... View app at
# Output 0 (base model): SELECT * FROM `table_16670746` WHERE  `winning_driver` =
# 'Jenson Button' AND    circuit = '<NAME>';<commit_msg>Update
# task3a.md<commit_after>---
# layout: post
# title: Task #3A - Text To Query Modeling Challenge [Part A] | IBM Watson Data
# Platform Developer Challenge @IBMWatson
# ---
#
# ⠙ Worker assigned... View app at
# In this part of challenge you will be building your own customizable natural
# language processing system for answering queries on data stored in relational
# databases using Apache Spark. The goal here it’s not just getting an accurate
# result but also being able customize how results should look like by providing
# different parameters such as column names etc.. This way we can make sure our
# models work with any kind of dataset without having too much knowledge from
# developers side what columns they have inside their DBMS systems so far! In
# other words if someone wants his/her application talk directly into some
# specific fields within certain rows then he needs only pass those values through
# API call instead trying figure out which ones exist beforehand – makes sense
# right? So let get started! :)
# ⠹ Worker assigned... View app at
# ***********************************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# ************ Row {idx} ************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# Input 1: {'input': 'Which surface do opponents of Thomas Oger Nicolas Tourte
# have?', 'context': 'CREATE TABLE table_name_18 (surface VARCHAR, opponents
# VARCHAR)', 'output': 'SELECT surface FROM table_name_18 WHERE opponents =
# "thomas oger nicolas tourte"'}
# ⠹ Worker assigned... View app at
# Output 1 (finetuned model): SELECT DISTINCT(opponents) FROM `table_name_18`
# WHERE 'Thomas' = "opponents" AND ('Oger', '<NAME>') IN ("surface") ORDER BY
# opponent DESC LIMIT 1;
# ⠹ Worker assigned... View app at
# Output 1 (base model): SELECT * FROM `table_name_18` WHERE 'opponents' =
# "Thomas" AND ('Oger', 'Nicolas') IN ("Tourte")<commit_msg>Update t2s.md
# (#309)<commit_after>---
# layout: problem
# title: Text to Structured Query Language - T2SQA
# tags: [text, sql]
# ⠹ Worker assigned... View app at
# description: A simple but challenging dataset for learning structured queries
# from natural language descriptions in an unsupervised manner using deep learning
# techniques such as recurrent neural networks with attention mechanisms over word
# embeddings trained on large corpora like Wikipedia. The goal here was not only
# training models capable at answering complex logical queries expressed through
# English sentences by reading them out loudly without any prior knowledge
# whatsoever; rather it also aimed towards building robust systems which can learn
# new facts/concepts when exposed repeatedly during inference time itself! This
# project aims both ways – i.e., generating meaningful outputs while
# simultaneously improving performance metrics related specifically designed tasks
# within this domain area called “Text To Structured Queries”.
# ⠹ Worker assigned... View app at
# ***********************************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# ************ Row {idx} ************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# Input 2: {'input': 'What is the extra result of the 4th game?', 'context':
# 'CREATE TABLE table_name_37 (extra VARCHAR, result VARCHAR)', 'output': 'SELECT
# extra FROM table_name_37 WHERE result = "4th"'}
# ⠹ Worker assigned... View app at
# Output 2 (finetuned model): SELECT `extra` FROM "table_name_37" WHERE
# row_number() OVER(ORDER BY id DESC) = 4;
# ⠹ Worker assigned... View app at
# Output 2 (base model): SELECT * FROM `table_name_37` WHERE EXTRA ='result' ORDER
# BY RAND() LIMIT 1;
# ⠹ Worker assigned... View app at
# ***********************************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# ************ Row {idx} ************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# Input 3: {'input': 'What school has the new conference as SELC?', 'context':
# 'CREATE TABLE table_26476336_2 (institution VARCHAR, new_conference VARCHAR)',
# 'output': 'SELECT institution FROM table_26476336_2 WHERE new_conference =
# "SELC"'}
# ⠹ Worker assigned... View app at
# Output 3 (finetuned model): SELECT institution FROM `table_26476336` WHERE
# new_conference = 'SELC';
# ⠹ Worker assigned... View app at
# Output 3 (base model): SELECT institution FROM `table_26476336` WHERE
# NEW_CONFERENCE = 'SEL'
# ⠹ Worker assigned... View app at
# ***********************************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# ************ Row {idx} ************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# Input 4: {'input': 'For the event held in Tartu, Estonia, what is the name of
# the runner-up?', 'context': 'CREATE TABLE table_name_90 (runner_up VARCHAR,
# venue VARCHAR)', 'output': 'SELECT runner_up FROM table_name_90 WHERE venue =
# "tartu, estonia"'}
# ⠹ Worker assigned... View app at
# Output 4 (finetuned model): SELECT * FROM `table_name_91` WHERE winner = 'Joe'
# AND second_place = '<NAME>'
# ⠹ Worker assigned... View app at
# Output 4 (base model): SELECT * FROM `table_name_91` WHERE id = '2' AND winner =
# '<NAME>' ORDER BY time DESC LIMIT 1;
# ⠹ Worker assigned... View app at
# ***********************************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# ************ Row {idx} ************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# Input 5: {'input': 'Name the number of players from arizona', 'context': 'CREATE
# TABLE table_15621965_10 (player VARCHAR, school_club_team VARCHAR)', 'output':
# 'SELECT COUNT(player) FROM table_15621965_10 WHERE school_club_team =
# "Arizona"'}
# ⠹ Worker assigned... View app at
# Output 5 (finetuned model): SELECT player FROM `table_15621965_10` WHERE team =
# 'arizona' LIMIT 1;
# ⠹ Worker assigned... View app at
# Output 5 (base model): SELECT player FROM `table_15621965_10` WHERE team =
# 'arizona' LIMIT 1;
# ⠹ Worker assigned... View app at
# ***********************************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# ************ Row {idx} ************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# Input 6: {'input': 'What is the title of the Misfits with a CD format?',
# 'context': 'CREATE TABLE table_name_67 (title VARCHAR, format VARCHAR, artist
# VARCHAR)', 'output': 'SELECT title FROM table_name_67 WHERE format = "cd" AND
# artist = "misfits"'}
# ⠹ Worker assigned... View app at
# Output 6 (finetuned model): SELECT * FROM `table_name_67` WHERE 'CD' = format
# AND artitst LIKE '%Misfits%';<commit_msg>Update
# misfits10k25q3.md<commit_after>---
# layout: problem
# number: 10k25q3
# title: "Misfits"
# tags: [text-to-sql]
# published: true
# solved: false   # True if the problem has been solved. False otherwise.
# hint: ""         # Optional hint for the problem.
# sample_input: |
#   Title     Format      Artist                               Title
# Format       Artist
# --------------------------------------------------------------------------------
# ------------------
# ⠹ Worker assigned... View app at
# The Cramps Rockabilly The Ramones Punk/New Wave            Rock & Roll   1950 -
# Present Day New York City USA United States Of America U.S./U.K..Australia
# Australia AUS AUSTRALIA OZ UK US N.Y.C NY NYC NEW YORK UNITED STATES OF AMERICA
# LOS ANGELES CA California SAN FRANCISCO SF San Francisco BERLIN GERMANY Berlin
# Germany DEUT
# ⠹ Worker assigned... View app at
# Output 6 (base model): SELECT * FROM `table_name_67` WHERE "title" = 'Misfits'
# AND ("format" = 'CD') ORDER BY RAND() LIMIT 1;
# ⠹ Worker assigned... View app at
# ***********************************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# ************ Row {idx} ************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# Input 7: {'input': 'When it is week 2 what is the record?', 'context': 'CREATE
# TABLE table_14941284_1 (record VARCHAR, week VARCHAR)', 'output': 'SELECT record
# FROM table_14941284_1 WHERE week = 2'}
# ⠹ Worker assigned... View app at
# Output 7 (finetuned model): SELECT * FROM `table_14941284_1` WHERE "record" =
# 'week' AND "week" = '2';<commit_msg>Update t2s.md (#305)<commit_after>---
# layout: problem
# title: Text-to-SQL Model - Week Two Question Answering Problem Set #6 [Easy]
# (T2S) | Codeforces Round #741 (Div. 2)
# problem_id: T2S
# ⠹ Worker assigned... View app at
# tags: data structures, string processing algorithms, graph traversal algorithm
# s, tree search algos., dynamic programming solutions for array problems in
# c++/java with time complexity analysis of each solution using big O notation.
# binary trees preorder post order level order recursion stack queue linked list
# implementation examples code snippets from scratch without any library support
# like geeksforgeeks hackerrank leetcode codeforces interviewbit etc..
# ⠹ Worker assigned... View app at
# Output 7 (base model): SELECT * FROM `table_14941284` WHERE 'week' = "WEEK" AND
# 'record'=="RECORD";
# ⠹ Worker assigned... View app at
# ***********************************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# ************ Row {idx} ************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# Input 8: {'input': 'What was the win/loss record for All Neutral games for the
# team whose Big 10 winning percentage was .833?', 'context': 'CREATE TABLE
# table_18135572_2 (all_neutral VARCHAR, b10__percentage VARCHAR)', 'output':
# 'SELECT all_neutral FROM table_18135572_2 WHERE b10__percentage = ".833"'}
# ⠹ Worker assigned... View app at
# Output 8 (finetuned model): SELECT all_neutral FROM `table_18135572` WHERE
# ((b10__percentage = '0.833') AND (((all_neutral = 'W') OR (all_neutral =
# 'L'))));<commit_msg>Update sql-query-answering.md (#3496)<commit_after>---
# layout: problem
# ⠹ Worker assigned... View app at
# title: Text-to-SQL Query Answering - Kaggle Competition Problem Statement
# [Kaggle] #####  [Problem ID :
# kaggle-sql-query-answering](https://www.kaggle.com/c/sql-query-answering) ####
# ## ### **PART 1** --- > This part of this competition focuses on answering
# queries using only natural language input as opposed to previous parts which
# focused primarily upon generating structured data from unstructured inputs such
# as images.<br> <br> The goal in this section will be similar but instead you'll
# need use your knowledge gained by solving Part I & II along with some new
# techniques learned here to generate an appropriate set of SQL commands based off
# user provided information! To do so we will be using our own custom dataset
# consisting entirely of real
# ⠹ Worker assigned... View app at
# Output 8 (base model): SELECT all_neutral FROM `table_18135572` WHERE
# ((b10__percentage = '0.833')) AND ALL_NEUTRAL IS NOT NULL;
# ⠹ Worker assigned... View app at
# ***********************************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# ************ Row {idx} ************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# Input 9: {'input': 'What is the total number of losses against the Rajasthan
# Royals with more than 0 ties?', 'context': 'CREATE TABLE table_name_57 (lost
# VARCHAR, opposition VARCHAR, tied VARCHAR)', 'output': 'SELECT COUNT(lost) FROM
# table_name_57 WHERE opposition = "rajasthan royals" AND tied > 0'}
# ⠹ Worker assigned... View app at
# Output 9 (finetuned model): SELECT COUNT(*) FROM `table_name_57` WHERE lost =
# 'Rajasthan' AND tied > 0;
# ⠹ Worker assigned... View app at
# Output 9 (base model): SELECT COUNT(*) FROM `table_name_57` WHERE lost =
# 'Rajasthan' AND tie = 'Yes';<commit_msg>Update sql-question-answering.md
# (#24689)<commit_after>---
# layout: problem
# title: Text-to-SQL Question Answering - Kaggle Cup 2017 Qualification Round A
# type: kagglecup
# tags: [kaggle]
# difficulty: medium
# reward: 300
# status: open
# solved: false
# problem_id: t2sqlqa
# forums_url:
# https://discuss.codechef.com/t/text-to-sql-question-answering-kaggle-cup-2017-qu
# alification-round-a/2556
# ---
#
# ⠹ Worker assigned... View app at
# **Problem Statement:** The goal in this task was for you as an AI agent trained
# on natural language processing tasks such as question answering using machine
# learning models like LSTMs etc.,  is now asked by your client if it can be used
# at scale across all their data sets which contain millions upon billions rows
# from various databases containing
# ⠹ Worker assigned... View app at
# ***********************************hat3jK4K8QwKyv
# ⠹ Worker assigned... View app at
# ⠹ Worker assigned... View app at
# https://modal.com/apps/ap-JS10MTVAhat3jK4K8QwKyv
# Timed out waiting for logs. View logs at
# https://modal.com/logs/ap-JS10MTVAhat3jK4K8QwKyv for remaining output.
# ✓ App completed.

# %% [markdown]
# ### Integrate Model with LlamaIndex
#
# Now that the model is finetuned, the checkpoints and model binary are stored in a model directory (by default it is in `/vol/data_sql`).
#
# We can now use this model in LlamaIndex for text-to-SQL applications.
#
# Specifically, we provide an interface allowing users to define any `sqlite` data file, and then they can run queries over this data file. We first create and dump a sample `cities.db` file containing (city, population, country) tuples. We then run inference over this file.

# %% [markdown]
# #### Create sample db

# %%
# create sample 
from sqlalchemy import (
    create_engine,
    MetaData,
    Table,
    Column,
    String,
    Integer,
    select,
    column,
)

# %%
db_file = "cities.db"
engine = create_engine(f"sqlite:///{db_file}")
metadata_obj = MetaData()

# %%
# create city SQL table
table_name = "city_stats"
city_stats_table = Table(
    table_name,
    metadata_obj,
    Column("city_name", String(16), primary_key=True),
    Column("population", Integer),
    Column("country", String(16), nullable=False),
)
metadata_obj.create_all(engine)

# %%
# insert sample rows
from sqlalchemy import insert

rows = [
    {"city_name": "Toronto", "population": 2930000, "country": "Canada"},
    {"city_name": "Tokyo", "population": 13960000, "country": "Japan"},
    {"city_name": "Chicago", "population": 2679000, "country": "United States"},
    {"city_name": "Seoul", "population": 9776000, "country": "South Korea"},
]
for row in rows:
    stmt = insert(city_stats_table).values(**row)
    with engine.connect() as connection:
        cursor = connection.execute(stmt)
        connection.commit()

# %% [markdown]
# #### Run Inference

# %%
query = "Which city has the highest population?"

# !modal run src.inference_sql_llamaindex::main --query '{query}' --sqlite-file-path {db_file} --model-dir "data_sql" --use-finetuned-model True
# Out:
# ✓ Initialized. View app at https://modal.com/apps/ap-BjYd5um2Efz70MftYxlyzE
# ⠋ Initializing...
# ⠹ Creating objects...objects...
# ├── ⠋ Creating download_models...
# └── ⠋ Creating mount /Users/jerryliu/Programming/modal_finetune_sql/src:
# ⠴ Creating objects...
# ├── ⠸ Creating download_models...
# └── ⠸ Creating mount /Users/jerryliu/Programming/modal_finetune_sql/src:
# ⠏ Creating objects...
# ├── ⠦ Creating download_models...
# ⠹ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ⠴ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ⠇ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠋ Creating run_query...
# └── ⠋ Creating mount /Users/jerryliu/Programming/modal_finetune_sql/src:
# ⠙ Creating objects...
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠸ Creating run_query...
# ⠼ Creating objects...amming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created run_query.
# └── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ✓ Created objects.
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created run_query.
# └── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ⠦ Worker assigned... View app at
# ⠴ Loading images (1 containers initializing)... View app at /ap-BjYd5um2Efz70MftYxlyzElyzE
# ⠏ Loading images (1 containers initializing)... View app at
# ⠹ Loading images (1 containers initializing)... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠴ Running (0/1 containers active)... View app at
# ⠇ Running (0/1 containers active)... View app at
# ⠙ Running (0/1 containers active)... View app at
# ⠼ Running (0/1 containers active)... View app at
# ⠧ Running (0/1 containers active)... View app at
# ⠙ Running (0/1 containers active)... View app at
# ⠼ Running (0/1 containers active)... View app at
# ⠧ Running (0/1 containers active)... View app at
# ⠋ Running (0/1 containers active)... View app at
# ⠸ Running (0/1 containers active)... View app at
# ⠧ Running (0/1 containers active)... View app at
# ⠋ Running (0/1 containers active)... View app at
# ⠸ Running (0/1 containers active)... View app at
# ⠦ Running (0/1 containers active)... View app at
# ⠏ Running (0/1 containers active)... View app at
# ⠹ Running (0/1 containers active)... View app at
# ⠦ Running (0/1 containers active)... View app at
# ⠏ Running (0/1 containers active)... View app at
# ⠹ Running (0/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# setting up service context5um2Efz70MftYxlyzE
# ⠇ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# s://modal.com/apps/ap-BjYd5um2Efz70MftYxlyzE
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# ⠋ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# s://modal.com/apps/ap-BjYd5um2Efz70MftYxlyzE
# ⠴ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ⠼ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at 19s/it]⠸ Running (1/1 containers active)... View app at https://modal.com/apps/ap-BjYd5
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# s://modal.com/apps/ap-BjYd5um2Efz70MftYxlyzE
# ⠧ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ...
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# open_ai Nonem/apps/ap-BjYd5um2Efz70MftYxlyzE
# ******
# Could not load OpenAIEmbedding. Using HuggingFaceBgeEmbeddings with model_name=BAAI/bge-small-en. Please check your API key if you intended to use OpenAI embeddings.
# ******
# ⠙ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# s://modal.com/apps/ap-BjYd5um2Efz70MftYxlyzE
# Downloading (…)ab102/.gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]Downloading (…)ab102/.gitattributes: 100%|██████████| 1.52k/1.52k [00:00<00:00, 244kB/s]
# ⠸ Running (1/1 containers active)... View app at https://modal.com/apps/ap-BjYd5
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]Downloading (…)_Pooling/config.json: 100%|██████████| 190/190 [00:00<00:00, 185kB/s]
# ⠼ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# s://modal.com/apps/ap-BjYd5um2Efz70MftYxlyzE
# Downloading (…)2d2d7ab102/README.md:   0%|          | 0.00/78.9k [00:00<?, ?B/s]Downloading (…)2d2d7ab102/README.md: 100%|██████████| 78.9k/78.9k [00:00<00:00, 23.7MB/s]
# ⠼ Running (1/1 containers active)... View app at https://modal.com/apps/ap-BjYd5
# Downloading (…)2d7ab102/config.json:   0%|          | 0.00/684 [00:00<?, ?B/s]Downloading (…)2d7ab102/config.json: 100%|██████████| 684/684 [00:00<00:00, 791kB/s]
# ⠴ Running (1/1 containers active)... View app at https://modal.com/apps/ap-BjYd5
# Downloading (…)ce_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]Downloading (…)ce_transformers.json: 100%|██████████| 124/124 [00:00<00:00, 155kB/s]
# ⠧ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# s://modal.com/apps/ap-BjYd5um2Efz70MftYxlyzE
# Downloading model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]9mView app at https://modal.com/apps/ap-BjYd5
# ⠋ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# Downloading model.safetensors:   8%|▊         | 10.5M/133M [00:00<00:01, 96.8MB/s]
# Downloading model.safetensors:  24%|██▎       | 31.5M/133M [00:00<00:00, 160MB/s]pp at https://modal.com/apps/ap-BjYd5
# ⠸ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# Downloading model.safetensors:  47%|████▋     | 62.9M/133M [00:00<00:00, 192MB/s]
# Downloading model.safetensors:  71%|███████   | 94.4M/133M [00:00<00:00, 205MB/s]pp at https://modal.com/apps/ap-BjYd5
# ⠦ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# Downloading model.safetensors:  86%|████████▋ | 115M/133M [00:00<00:00, 204MB/s] Downloading model.safetensors: 100%|██████████| 133M/133M [00:00<00:00, 194MB/s]
# ⠧ Running (1/1 containers active)... View app at https://modal.com/apps/ap-BjYd5
# Downloading pytorch_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]9mView app at https://modal.com/apps/ap-BjYd5
# ⠋ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# Downloading pytorch_model.bin:  24%|██▎       | 31.5M/134M [00:00<00:00, 238MB/s]
# Downloading pytorch_model.bin:  47%|████▋     | 62.9M/134M [00:00<00:00, 229MB/s]pp at https://modal.com/apps/ap-BjYd5
# ⠸ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# Downloading pytorch_model.bin:  71%|███████   | 94.4M/134M [00:00<00:00, 226MB/s]
# Downloading pytorch_model.bin:  94%|█████████▍| 126M/134M [00:00<00:00, 222MB/s] Downloading pytorch_model.bin: 100%|██████████| 134M/134M [00:00<00:00, 222MB/s]
# ⠦ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# s://modal.com/apps/ap-BjYd5um2Efz70MftYxlyzE
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]Downloading (…)nce_bert_config.json: 100%|██████████| 52.0/52.0 [00:00<00:00, 45.3kB/s]
# ⠦ Running (1/1 containers active)... View app at https://modal.com/apps/ap-BjYd5
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]Downloading (…)cial_tokens_map.json: 100%|██████████| 125/125 [00:00<00:00, 81.3kB/s]
# ⠧ Running (1/1 containers active)... View app at https://modal.com/apps/ap-BjYd5
# ⠏ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# Downloading (…)ab102/tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]Downloading (…)ab102/tokenizer.json: 100%|██████████| 711k/711k [00:00<00:00, 9.39MB/s]
# ⠏ Running (1/1 containers active)... View app at https://modal.com/apps/ap-BjYd5
# Downloading (…)okenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]Downloading (…)okenizer_config.json: 100%|██████████| 366/366 [00:00<00:00, 385kB/s]
# ⠋ Running (1/1 containers active)... View app at https://modal.com/apps/ap-BjYd5
# Downloading (…)2d2d7ab102/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]Downloading (…)2d2d7ab102/vocab.txt: 100%|██████████| 232k/232k [00:00<00:00, 26.4MB/s]
# ⠹ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# s://modal.com/apps/ap-BjYd5um2Efz70MftYxlyzE
# Downloading (…)d7ab102/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]Downloading (…)d7ab102/modules.json: 100%|██████████| 229/229 [00:00<00:00, 320kB/s]
# ⠴ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# ⠏ Running (1/1 containers active)... View app at
# [nltk_data] Downloading package punkt to /tmp/llama_index...
# ⠹ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ⠴ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# ⠇ Running (1/1 containers active)... View app at
# 2023-08-16 23:30:14,499 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-08-16 23:30:14,499 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# ⠙ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:14,499 INFO sqlalchemy.engine.Engine [raw sql] ()
# ⠴ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:15,103 INFO sqlalchemy.engine.Engine ROLLBACK
# 2023-08-16 23:30:15,104 INFO sqlalchemy.engine.Engine BEGIN (implicit)38;5;249mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:15,104 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2023-08-16 23:30:15,104 INFO sqlalchemy.engine.Engine [raw sql] ()0mView app at https://modal.com/apps/ap-BjYd5
# ⠇ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:15,304 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_temp_master WHERE type='table' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2023-08-16 23:30:15,304 INFO sqlalchemy.engine.Engine [raw sql] ()0mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:15,304 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("city_stats")https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:15,304 INFO sqlalchemy.engine.Engine [raw sql] ()0mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:15,501 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# ⠙ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:15,501 INFO sqlalchemy.engine.Engine [raw sql] ('city_stats',)
# 2023-08-16 23:30:15,705 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("city_stats")https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:15,705 INFO sqlalchemy.engine.Engine [raw sql] ()0mView app at https://modal.com/apps/ap-BjYd5
# ⠼ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:15,705 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("city_stats")
# 2023-08-16 23:30:15,705 INFO sqlalchemy.engine.Engine [raw sql] ()0mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:15,705 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-08-16 23:30:15,706 INFO sqlalchemy.engine.Engine [raw sql] ('city_stats',)View app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:15,908 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("city_stats") https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:15,908 INFO sqlalchemy.engine.Engine [raw sql] ()0mView app at https://modal.com/apps/ap-BjYd5
# ⠧ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:16,108 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("city_stats")
# 2023-08-16 23:30:16,109 INFO sqlalchemy.engine.Engine [raw sql] ()0mView app at https://modal.com/apps/ap-BjYd5
# ⠋ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:16,305 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("city_stats")
# 2023-08-16 23:30:16,305 INFO sqlalchemy.engine.Engine [raw sql] ()0mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:16,501 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("sqlite_autoindex_city_stats_1")ttps://modal.com/apps/ap-BjYd5
# ⠼ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:16,501 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-16 23:30:16,697 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-08-16 23:30:16,697 INFO sqlalchemy.engine.Engine [raw sql] ('city_stats',)View app at https://modal.com/apps/ap-BjYd5
# ⠧ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:16,896 INFO sqlalchemy.engine.Engine ROLLBACK
# 2023-08-16 23:30:16,897 INFO sqlalchemy.engine.Engine BEGIN (implicit)38;5;249mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:16,897 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("city_stats")https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:16,897 INFO sqlalchemy.engine.Engine [raw sql] ()0mView app at https://modal.com/apps/ap-BjYd5
# ⠋ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:17,094 INFO sqlalchemy.engine.Engine ROLLBACK
# 2023-08-16 23:30:17,095 INFO sqlalchemy.engine.Engine BEGIN (implicit)38;5;249mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:17,095 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("city_stats")https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:17,095 INFO sqlalchemy.engine.Engine [raw sql] ()0mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:17,095 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("city_stats")https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:17,095 INFO sqlalchemy.engine.Engine [raw sql] ()0mView app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:17,096 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-08-16 23:30:17,096 INFO sqlalchemy.engine.Engine [raw sql] ('city_stats',)View app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:17,295 INFO sqlalchemy.engine.Engine ROLLBACKm View app at https://modal.com/apps/ap-BjYd5
# ⠸ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# 2023-08-16 23:30:21,908 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-08-16 23:30:21,909 INFO sqlalchemy.engine.Engine SELECT MAX(population) FROM city_stats WHERE country = "United States"m/apps/ap-BjYd5
# 2023-08-16 23:30:21,909 INFO sqlalchemy.engine.Engine [generated in 0.00074s] ()iew app at https://modal.com/apps/ap-BjYd5
# 2023-08-16 23:30:22,111 INFO sqlalchemy.engine.Engine ROLLBACKm View app at https://modal.com/apps/ap-BjYd5
# ⠼ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-BjYd5
# ⠼ Running (1/1 containers active)... View app at
# https://modal.com/apps/ap-BjYd5um2Efz70MftYxlyzE
# Model output: SELECT MAX(population) FROM city_stats WHERE country = "United States"
# Runner terminated, in-progress inputs will be re-scheduled
# ✓ App completed.

# %%
# you can also choose to run the original (nonfinetuned model) to compare results
# note: it throws an error 

# use non-finetuned model
# !modal run src.inference_sql_llamaindex::main --query '{query}' --sqlite-file-path {db_file} --model-dir "data_sql" --use-finetuned-model False
# Out:
# ✓ Initialized. View app at https://modal.com/apps/ap-1n1QmIubsUDYdMnVNCTGzh
# ⠋ Initializing...
# ⠹ Creating objects...objects...
# ├── ⠋ Creating download_models...
# └── ⠋ Creating mount /Users/jerryliu/Programming/modal_finetune_sql/src:
# ⠴ Creating objects...
# ├── ⠸ Creating download_models...
# └── ⠸ Creating mount /Users/jerryliu/Programming/modal_finetune_sql/src:
# ⠏ Creating objects...
# ├── 🔨 Created download_models.
# ⠹ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ⠴ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ⠇ Creating objects...s/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠋ Creating run_query...
# └── ⠋ Creating mount /Users/jerryliu/Programming/modal_finetune_sql/src:
# ⠙ Creating objects...
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── ⠸ Creating run_query...
# ⠸ Creating objects...amming/modal_finetune_sql/src
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created run_query.
# └── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ✓ Created objects.
# ├── 🔨 Created download_models.
# ├── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ├── 🔨 Created run_query.
# └── 🔨 Created mount /Users/jerryliu/Programming/modal_finetune_sql/src
# ⠦ Worker assigned... View app at
# ⠏ Worker assigned... View app at
# ⠴ Loading images (1 containers initializing)... View app at com/apps/ap-1n1QmIubsUDYdMnVNCTGzh
# ⠏ Loading images (1 containers initializing)... View app at
# ⠹ Loading images (1 containers initializing)... View app at
# ⠴ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠼ Loading images (1 containers initializing)... View app at
# ⠇ Loading images (1 containers initializing)... View app at
# ⠙ Loading images (1 containers initializing)... View app at
# ⠼ Loading images (1 containers initializing)... View app at
# ⠧ Loading images (1 containers initializing)... View app at
# ⠋ Running (0/1 containers active)... View app at
# ⠼ Running (0/1 containers active)... View app at
# ⠧ Running (0/1 containers active)... View app at
# ⠋ Running (0/1 containers active)... View app at
# ⠸ Running (0/1 containers active)... View app at
# ⠦ Running (0/1 containers active)... View app at
# ⠋ Running (0/1 containers active)... View app at
# ⠸ Running (0/1 containers active)... View app at
# ⠦ Running (0/1 containers active)... View app at
# ⠏ Running (0/1 containers active)... View app at
# ⠹ Running (0/1 containers active)... View app at
# ⠦ Running (0/1 containers active)... View app at
# ⠏ Running (0/1 containers active)... View app at
# ⠹ Running (0/1 containers active)... View app at
# ⠴ Running (0/1 containers active)... View app at
# ⠇ Running (0/1 containers active)... View app at
# ⠹ Running (0/1 containers active)... View app at
# ⠴ Running (0/1 containers active)... View app at
# ⠇ Running (0/1 containers active)... View app at
# ⠙ Running (0/1 containers active)... View app at
# ⠼ Running (0/1 containers active)... View app at
# ⠧ Running (0/1 containers active)... View app at
# ⠙ Running (0/1 containers active)... View app at
# ⠼ Running (0/1 containers active)... View app at
# ⠧ Running (0/1 containers active)... View app at
# ⠋ Running (0/1 containers active)... View app at
# ⠸ Running (0/1 containers active)... View app at
# ⠧ Running (0/1 containers active)... View app at
# ⠋ Running (0/1 containers active)... View app at
# ⠸ Running (0/1 containers active)... View app at
# ⠦ Running (0/1 containers active)... View app at
# ⠏ Running (0/1 containers active)... View app at
# ⠸ Running (0/1 containers active)... View app at
# ⠦ Running (0/1 containers active)... View app at
# ⠏ Running (0/1 containers active)... View app at
# ⠹ Running (0/1 containers active)... View app at
# ⠴ Running (0/1 containers active)... View app at
# ⠏ Running (0/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# setting up service contextmIubsUDYdMnVNCTGzh
# ⠇ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-1n1Qm
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# s://modal.com/apps/ap-1n1QmIubsUDYdMnVNCTGzh
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# ⠸ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-1n1Qm
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# s://modal.com/apps/ap-1n1QmIubsUDYdMnVNCTGzh
# ⠙ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-1n1Qm
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ⠼ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-1n1Qm
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at 71s/it]⠸ Running (1/1 containers active)... View app at https://modal.com/apps/ap-1n1Qm
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# s://modal.com/apps/ap-1n1QmIubsUDYdMnVNCTGzh
# ⠸ Running (1/1 containers active)... View app at 9mView app at https://modal.com/apps/ap-1n1Qm
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at 00s/it]⠙ Running (1/1 containers active)... View app at https://modal.com/apps/ap-1n1Qm
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ...
#     return self._exec_single_context(
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1984, in _exec_single_context
#     self._handle_dbapi_exception(
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 2339, in _handle_dbapi_exception
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1965, in _exec_single_context
#     self.dialect.do_execute(
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 921, in do_execute
#     cursor.execute(statement, parameters)
# sqlalchemy.exc.OperationalError: (sqlite3.OperationalError) unrecognized token: "#"
# [SQL: SELECT city_name, population, country
# FROM city_stats
# WHERE population = (SELECT MAX(population) FROM city_stats)
#
# ### Output:
#
# ```sql
# SELECT city_name, population, country
# FROM city_stats
# WHERE population = (SELECT MAX(population) FROM city_stats)
# ```
#
# ### Example:
#
# ```sql
# SELECT city_name, population, country
# FROM city_stats
# WHERE population = (SELECT MAX(population) FROM city_stats)
# ```
#
# ### Output:
#
# ```sql
# SELECT city_name, population, country
# FROM city_stats
# WHERE population = (SELECT MAX(population) FROM city_stats)
# ```
#
# ### Example:
#
# ```sql
# SELECT city_name, population, country
# FROM city_stats
# WHERE population = (SELECT MAX(population) FROM city_stats)
# ```
#
# ### Output:
#
# ```sql
# SELECT city_name, population, country
# FROM city_stats
# WHERE population]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Runner terminated, in-progress inputs will be re-scheduled
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /Users/jerryliu/Programming/modal_finetune_sql/.venv/bin/modal:8 in <module> │
# │                                                                              │
# │   7 │   sys.argv[0] = re.sub(r'(-script\.pyw|\.exe)?$', '', sys.argv[0])     │
# │ ❱ 8 │   sys.exit(main())                                                     │
# │   9                                                                          │
# │                                                                              │
# │ /Users/jerryliu/Programming/modal_finetune_sql/.venv/lib/python3.10/site-pac │
# │ kages/modal/__main__.py:6 in main                                            │
# │                                                                              │
# │    5 def main():                                                             │
# │ ❱  6 │   entrypoint_cli()                                                    │
# │    7                                                                         │
# │                                                                              │
# │ /Users/jerryliu/Programming/modal_finetune_sql/.venv/lib/python3.10/site-pac │
# │ kages/click/core.py:1157 in __call__                                         │
# │                                                                              │
# │   1156 │   │   """Alias for :meth:`main`."""                                 │
# │ ❱ 1157 │   │   return self.main(*args, **kwargs)                             │
# │   1158                                                                       │
# │                                                                              │
# │ /Users/jerryliu/Programming/modal_finetune_sql/.venv/lib/python3.10/site-pac │
# │ kages/typer/core.py:778 in main                                              │
# │                                                                              │
# │   777 │   ) -> Any:                                                          │
# │ ❱ 778 │   │   return _main(                                                  │
# │   779 │   │   │   self,                                                      │
# │                                                                              │
# │ /Users/jerryliu/Programming/modal_finetune_sql/.venv/lib/python3.10/site-pac │
# │ kages/typer/core.py:216 in _main                                             │
# │                                                                              │
# │   215 │   │   │   with self.make_context(prog_name, args, **extra) as ctx:   │
# │ ❱ 216 │   │   │   │   rv = self.invoke(ctx)                                  │
# │   217 │   │   │   │   if not standalone_mode:                                │
# │                                                                              │
# │ /Users/jerryliu/Programming/modal_finetune_sql/.venv/lib/python3.10/site-pac │
# │ kages/click/core.py:1688 in invoke                                           │
# │                                                                              │
# │   1687 │   │   │   │   with sub_ctx:                                         │
# │ ❱ 1688 │   │   │   │   │   return _process_result(sub_ctx.command.invoke(sub │
# │   1689                                                                       │
# │                                                                              │
# │ /Users/jerryliu/Programming/modal_finetune_sql/.venv/lib/python3.10/site-pac │
# │ kages/click/core.py:1688 in invoke                                           │
# │                                                                              │
# │   1687 │   │   │   │   with sub_ctx:                                         │
# │ ❱ 1688 │   │   │   │   │   return _process_result(sub_ctx.command.invoke(sub │
# │   1689                                                                       │
# │                                                                              │
# │ /Users/jerryliu/Programming/modal_finetune_sql/.venv/lib/python3.10/site-pac │
# │ kages/click/core.py:1434 in invoke                                           │
# │                                                                              │
# │   1433 │   │   if self.callback is not None:                                 │
# │ ❱ 1434 │   │   │   return ctx.invoke(self.callback, **ctx.params)            │
# │   1435                                                                       │
# │                                                                              │
# │ /Users/jerryliu/Programming/modal_finetune_sql/.venv/lib/python3.10/site-pac │
# │ kages/click/core.py:783 in invoke                                            │
# │                                                                              │
# │    782 │   │   │   with ctx:                                                 │
# │ ❱  783 │   │   │   │   return __callback(*args, **kwargs)                    │
# │    784                                                                       │
# │                                                                              │
# │ /Users/jerryliu/Programming/modal_finetune_sql/.venv/lib/python3.10/site-pac │
# │ kages/click/decorators.py:33 in new_func                                     │
# │                                                                              │
# │    32 │   def new_func(*args: "P.args", **kwargs: "P.kwargs") -> "R":        │
# │ ❱  33 │   │   return f(get_current_context(), *args, **kwargs)               │
# │    34                                                                        │
# │                                                                              │
# │ /Users/jerryliu/Programming/modal_finetune_sql/.venv/lib/python3.10/site-pac │
# │ kages/modal/cli/run.py:134 in f                                              │
# │                                                                              │
# │   133 │   │   │   else:                                                      │
# │ ❱ 134 │   │   │   │   func(*args, **kwargs)                                  │
# │   135 │   │   │   if app.client.function_invocations == 0:                   │
# │                                                                              │
# │ /Users/jerryliu/Programming/modal_finetune_sql/.venv/lib/python3.10/site-pac │
# │ kages/synchronicity/synchronizer.py:448 in f_wrapped                         │
# │                                                                              │
# │ /Users/jerryliu/Programming/modal_finetune_sql/src/inference_sql_llamaindex. │
# │ py:190 in main                                                               │
# │                                                                              │
# │   189 │   │   bool_toggle = use_finetuned_model == "True"                    │
# │ ❱ 190 │   │   run_query.call(query, model_dir=model_dir, use_finetuned_model │
# │   191                                                                        │
# │                                                                              │
# │ /Users/jerryliu/Programming/modal_finetune_sql/.venv/lib/python3.10/site-pac │
# │ kages/synchronicity/synchronizer.py:497 in proxy_method                      │
# │                                                                              │
# │ /Users/jerryliu/Programming/modal_finetune_sql/.venv/lib/python3.10/site-pac │
# │ kages/synchronicity/combined_types.py:26 in __call__                         │
# │                                                                              │
# │       ...Remote call to Modal Function (ta-0MOeU0j9oWZ7icEhrh7hvl)...        │
# │                                                                              │
# │ /root/src/inference_sql_llamaindex.py:171 in run_query                       │
# │                                                                              │
# │ ❱ 171 response = query_engine.query(query)                                   │
# │                                                                              │
# │                                                                              │
# │ /opt/conda/lib/python3.9/site-packages/llama_index/indices/query/base.py:23  │
# │ in query                                                                     │
# │                                                                              │
# │ ❱ 23 response = self._query(str_or_query_bundle)                             │
# │                                                                              │
# │                                                                              │
# │ /opt/conda/lib/python3.9/site-packages/llama_index/indices/struct_store/sql_ │
# │ query.py:275 in _query                                                       │
# │                                                                              │
# │ ❱ 275 raw_response_str, metadata = self._sql_database.run_sql(sql_query_str) │
# │                                                                              │
# │                                                                              │
# │ /opt/conda/lib/python3.9/site-packages/llama_index/langchain_helpers/sql_wra │
# │ pper.py:91 in run_sql                                                        │
# │                                                                              │
# │ ❱ 91 cursor = connection.execute(text(command))                              │
# │                                                                              │
# │                                                                              │
# │ /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1412 in     │
# │ execute                                                                      │
# │                                                                              │
# │ ❱ 1412 return meth(                                                          │
# │                                                                              │
# │                                                                              │
# │ /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/elements.py:483 in     │
# │ _execute_on_connection                                                       │
# │                                                                              │
# │ ❱ 483 return connection._execute_clauseelement(                              │
# │                                                                              │
# │                                                                              │
# │ /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1635 in     │
# │ _execute_clauseelement                                                       │
# │                                                                              │
# │ ❱ 1635 ret = self._execute_context(                                          │
# │                                                                              │
# │                                                                              │
# │ /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1844 in     │
# │ _execute_context                                                             │
# │                                                                              │
# │ ❱ 1844 return self._exec_single_context(                                     │
# │                                                                              │
# │                                                                              │
# │ /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1984 in     │
# │ _exec_single_context                                                         │
# │                                                                              │
# │ ❱ 1984 self._handle_dbapi_exception(                                         │
# │                                                                              │
# │                                                                              │
# │ /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2339 in     │
# │ _handle_dbapi_exception                                                      │
# │                                                                              │
# │ ❱ 2339 raise sqlalchemy_exception.with_traceback(exc_info[2]) from e         │
# │                                                                              │
# │                                                                              │
# │ /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1965 in     │
# │ _exec_single_context                                                         │
# │                                                                              │
# │ ❱ 1965 self.dialect.do_execute(                                              │
# │                                                                              │
# │                                                                              │
# │ /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/default.py:921 in   │
# │ do_execute                                                                   │
# │                                                                              │
# │ ❱ 921 cursor.execute(statement, parameters)                                  │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# OperationalError: (sqlite3.OperationalError) unrecognized token: "#"
# [SQL: SELECT city_name, population, country
# FROM city_stats
# WHERE population = (SELECT MAX(population) FROM city_stats)
#
# ### Output:
#
# ```sql
# SELECT city_name, population, country
# FROM city_stats
# WHERE population = (SELECT MAX(population) FROM city_stats)
# ```
#
# ### Example:
#
# ```sql
# SELECT city_name, population, country
# FROM city_stats
# WHERE population = (SELECT MAX(population) FROM city_stats)
# ```
#
# ### Output:
#
# ```sql
# SELECT city_name, population, country
# FROM city_stats
# WHERE population = (SELECT MAX(population) FROM city_stats)
# ```
#
# ### Example:
#
# ```sql
# SELECT city_name, population, country
# FROM city_stats
# WHERE population = (SELECT MAX(population) FROM city_stats)
# ```
#
# ### Output:
#
# ```sql
# SELECT city_name, population, country
# FROM city_stats
# WHERE population]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ### (Optional) Download Model
#
# If you want to download the model weights for your own use, just run the following script.

# %%
from src.download_weights import main

main("out_model", model_dir="data_sql")
